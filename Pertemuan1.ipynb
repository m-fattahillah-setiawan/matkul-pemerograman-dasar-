# %% [markdown]
# <a href="https://colab.research.google.com/github/m-fattahillah-setiawan/matkul-pemerograman-dasar-/blob/main/Pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Fatih"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False
Hobi = "Menulis"
Hobi2 = 'Badminton'
makanan_favorit = "Tahu"
status_nikah = False
jumlah_saudara = 2

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (Hobi)
print (Hobi2)
print (makanan_favorit)
print (status_nikah)
print (jumlah_saudara)
# Out:
# Fatih
# 20
# RPE
# 3
# Pemerograman Dasar
# False
# Menulis
# Badminton
# Tahu
# False
# 2
